# %%
# import necessary packages 
import pandas  
import numpy as np 
from rdkit import Chem
import networkx
from rdkit.Chem import AllChem
from io import StringIO
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import Descriptors3D
from IPython.display import SVG
from rdkit import Chem
from rdkit.Chem import rdDepictor
from rdkit.Chem.Draw import rdMolDraw2D

# %%
# import data frame of all data 
DataMat= pandas.read_csv("MolMatrix.csv", sep= ';')

 # remove erroneous columns if necessary
DataMat = DataMat.loc[:, ~DataMat.columns.str.contains('^Unnamed')]
DataMat.head(20)
# Out:
#    CSD_Code  Electronic_E  Dispersion_E  Dipole_M  Metal_q   HL_Gap  \
# 0    ILOJOK  -3314.579807     -0.287378    2.9470  1.77729  0.09247
# 1    OBIQAS  -2182.364646     -0.165425   13.2425  0.95356  0.09408
# 2    ZOBPEN  -2252.596426     -0.263845    4.6839  1.92393  0.10349
# 3    KETHAV  -1085.624629     -0.106185    1.8276  1.89356  0.15642
# 4    RUXTAH  -3916.912886     -0.290756    3.2622  1.12029  0.12116
# 5    WOLRIA  -1934.263822     -0.143611    3.5856  1.73467  0.13199
# 6    GACJAW  -1999.074241     -0.205098    7.3734  1.77909  0.12299
# 7    YIXHOE  -3380.956110     -0.180335    4.1099  1.16190  0.12814
# 8    VAQFAX  -3381.587804     -0.262134   10.8247  1.39478  0.11034
# 9    LURLUG  -2353.577963     -0.122106    4.2626  1.40565  0.14595
# 10   EGEKIL  -3495.215389     -0.218088    3.1609  0.76148  0.11758
# 11   RAKKAS  -1101.964833     -0.127823    1.2603  2.05167  0.11694
# 12   PIXGUZ  -2801.904824     -0.207864    5.8632  1.45486  0.11674
# 13   BUQHIF  -2163.198924     -0.210461    5.4970  1.86123  0.12360
# 14   XIQJEM  -3155.467375     -0.195567    4.4327  0.89868  0.13063
# 15   DUDTIH  -2620.497003     -0.144442    0.0403  0.96640  0.06965
# 16   UGEBEO  -3053.451555     -0.217075    2.8334  1.52294  0.11709
# 17   HUVRIA  -2715.836399     -0.170514    6.0046  1.46310  0.10960
# 18   QEJFOC  -1930.670378     -0.233760    4.7310  1.84602  0.10210
# 19   NAPKEW  -1681.969504     -0.154646    4.9396  1.93487  0.09738
#
#     HOMO_Energy  LUMO_Energy  Polarizability  \
# 0      -0.17508     -0.08261      726.729174
# 1      -0.30051     -0.20643      463.072163
# 2      -0.15361     -0.05012      630.762664
# 3      -0.18356     -0.02714      303.843529
# 4      -0.17208     -0.05092      681.659139
# 5      -0.17411     -0.04212      381.808553
# 6      -0.18405     -0.06106      511.174137
# 7      -0.18742     -0.05928      570.504772
# 8      -0.26940     -0.15906      638.486122
# 9      -0.19225     -0.04630      355.724755
# 10     -0.16673     -0.04915      540.784144
# 11     -0.15272     -0.03578      338.668258
# 12     -0.17998     -0.06324      525.683935
# 13     -0.19645     -0.07285      558.799426
# 14     -0.20453     -0.07390      470.745161
# 15     -0.18429     -0.11464      451.568946
# 16     -0.18930     -0.07221      571.489065
# 17     -0.18446     -0.07486      463.242364
# 18     -0.15017     -0.04807      546.259256
# 19     -0.16418     -0.06680      429.422193
#
#                                                SMILES      Stoichiometry  \
# 0   [Y]1234(N(c5c(cccc5C)C)[C]5C=CC=C(N15)N(c1c(cc...        C58H51F6N8Y
# 1   [La]12345(I)(I)[N@@](C[C]6N2C=CN=C6)(C[C]2N3C=...  C26H30I2LaN10(1+)
# 2   [Y]12(N([C](C)C=C(N1c1c(cccc1)C)C)c1c(cccc1)C)...          C50H60N5Y
# 3   [Y](c1c(OC)cccc1)([C@H]1C(=C(C(=C1C)C)C)C)[C@H...           C25H33OY
# 4   [Sc]123(S[P]([C@]3([Si](C)(C)C)[C@@H](N2C)c2cc...     C49H70N4PSScSi
# 5   [C]12[C@@H]([CH]c3c1cccc3)[Y](N(CCN(C)C)[Si](C...       C22H42N3Si3Y
# 6   [Y]12345Oc6c([CH][N@]3CC[N@](CC[N@@]4[CH]c3c(O...        C39H51N4O3Y
# 7   [Sc]123(OC(=C[C](O1)c1cn(nc1C)C)c1cn(nc1C)C)(O...      C39H45N12O6Sc
# 8   [Sc@]12([N@]([C](C=C(N1c1c(cccc1C(C)C)C(C)C)C)...  C50H67N2O3PSc(1+)
# 9   [Sc](C[Si](C)(C)C)(C[Si](C)(C)C)[C@@]1(C(=C(C(...       C24H41OScSi2
# 10  [Sc]12([P](c3cc(ccc3N1c1ccc(cc1[P]2(C(C)C)C(C)...     C38H58ClN2P2Sc
# 11  [C@]1(C(=C(C(=C1C)C)C)C)(C)[La]([C@]1(C(=C(C(=...          C26H42LaN
# 12  [Sc]1(N([P](c2c(N1c1c(cccc1C(C)C)C(C)C)cccc2)(...        C41H48N2PSc
# 13  [Y]123(n4c([N]C(C)C)c5ccccc5c4N1C(C)C)(n1c([N]...          C42H54N9Y
# 14  [Sc]1(Cl)(Cl)N(C(=C[C](N1c1c(cccc1C(C)C)C(C)C)...      C35H53Cl2N2Sc
# 15  [Sc]123([N]4=C5N=c6n1c(=NC1=[N]2C(=Nc2n3c(N=C4...         C37H21N8Sc
# 16  [Sc]1(N(C(=C[C](N1c1cc(cc(c1)C(C)(C)C)C(C)(C)C...      C41H71N2ScSi2
# 17  [Sc]12(N(C(=C[C]([N@]1C[C]1N2C=CC=C1)C)C)c1c(c...      C31H52N3ScSi2
# 18  [Y]12(N([C](C)C=C(N1CCN(C)C)C)c1c(cccc1C(C)C)C...          C40H67N6Y
# 19  C12=C(C(=C([C@H]1C)C)C)C[Y]1([C@]3(C(=C(C(=C3C...        C32H43N2SiY
#
#     Charge    S  MND
# 0        0  S=0    7
# 1        1  S=0    8
# 2        0  S=0    5
# 3        0  S=0   12
# 4        0  S=0    5
# 5        0  S=0    8
# 6        0  S=0    7
# 7        0  S=0    6
# 8        1  S=0    4
# 9        0  S=0    8
# 10       0  S=0    6
# 11       0  S=0   13
# 12       0  S=0    4
# 13       0  S=0    6
# 14       0  S=0    4
# 15       0  S=0    9
# 16       0  S=0    4
# 17       0  S=0    5
# 18       0  S=0    6
# 19       0  S=0   11

# %%
# make dataframe containing smiles and CSD code:
Mols = DataMat[['CSD_Code','SMILES']]

# %%
# analyze dataframe
Mols.head()
Mols.shape
# Out:
# (68123, 2)

# %%
# make a function that takes in SMILES and outputs descriptors
def descriptors(smiles):
    mol = Chem.MolFromSmiles(smiles)
    Descriptor_List=[
    'ExactMolWt',
    'FpDensityMorgan1',
    'FpDensityMorgan2',
    'FpDensityMorgan3',
    'HeavyAtomMolWt',
    'MolWt',
    'NumRadicalElectrons',
    'NumValenceElectrons',
     'Chi0',
     'Chi0n',
     'Chi0v',
     'Chi1',
     'Chi1n',
     'Chi1v',
     'Chi2n',
     'Chi2v',
     'Chi3n',
     'Chi3v',
     'Chi4n',
     'Chi4v',
    'Kappa1',
     'Kappa2',
     'Kappa3']
    Descriptor_values = np.zeros(len(Descriptor_List))
    c = 0
    for item in Descriptor_List:
        desc_call = "Chem.Descriptors.{}(mol)".format(item)
        Descriptor_values[c]=eval(desc_call)
        c+=1
    return Descriptor_values

# %%
# create descriptor list
Descriptor_List=[
    'ExactMolWt',
    'FpDensityMorgan1',
    'FpDensityMorgan2',
    'FpDensityMorgan3',
    'HeavyAtomMolWt',
    'MolWt',
    'NumRadicalElectrons',
    'NumValenceElectrons',
     'Chi0',
     'Chi0n',
     'Chi0v',
     'Chi1',
     'Chi1n',
     'Chi1v',
     'Chi2n',
     'Chi2v',
     'Chi3n',
     'Chi3v',
     'Chi4n',
     'Chi4v',
    'Kappa1',
     'Kappa2',
     'Kappa3']

# %%
# create description matrix columns
DescMat = pandas.DataFrame(columns=('SMILES','CSD_Code','ExactMolWt',
    'FpDensityMorgan1',
    'FpDensityMorgan2',
    'FpDensityMorgan3',
    'HeavyAtomMolWt',
    'MolWt',
    'NumRadicalElectrons',
    'NumValenceElectrons',
     'Chi0',
     'Chi0n',
     'Chi0v',
     'Chi1',
     'Chi1n',
     'Chi1v',
     'Chi2n',
     'Chi2v',
     'Chi3n',
     'Chi3v',
     'Chi4n',
     'Chi4v',
    'Kappa1',
     'Kappa2',
     'Kappa3'))

# %%
# modify description matrix
for i, r in Mols.iterrows():
    print(i)
    D = r['CSD_Code']
    S = r['SMILES']
    desc = descriptors(S)
    desc = desc.tolist()
    base = [S,D]
    for j in desc:
        base.append(j)
    DescMat.loc[len(DescMat)] = base

# %%
# append to description matrix
test = [S,D]
for i in desc:
    test.append(i)

DescMat.loc[len(DescMat)] = test

# %%
# analyze complete description matrix
DescMat

# %%
# remove unhandleable data
Datamat = DataMat.iloc[0:14094]

# %%
# analyze completed data matrix
Datamat

# %%
# merge data matrix with description matrix on CSD Code
ModelMat = pandas.merge(Datamat,DescMat,on = ['CSD_Code','CSD_Code'])

# %%
# analyze completed model matrix
ModelMat

# %%
# save the matrix to a file 
ModelMat.to_csv("ModelMat.csv",sep= ';')
